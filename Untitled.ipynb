# %%
import os
base = os.path.expanduser("~/Desktop/scrna-cell-heterogeneity-biomarkers")

files = [
    "src/__init__.py",
    "src/data_ingestion.py",
    "src/qc_preprocessing.py",
    "src/clustering_annotation.py",
    "src/trajectory_analysis.py",
    "src/de_enrichment.py",
    "src/ml_biomarker.py",
    "src/cell_communication.py",
    "src/dashboard.py",
    "configs/config.yaml",
    "Snakefile",
    "Dockerfile",
    "environment.yml",
    "data/download_instructions.md",
]

for f in files:
    full = os.path.join(base, f)
    os.makedirs(os.path.dirname(full), exist_ok=True)
    if not os.path.exists(full):
        open(full, "w").close()
        print(f"✓ {f}")
    else:
        print(f"  exists: {f}")

print(f"\nAll files ready!")
print("src/:", os.listdir(os.path.join(base, "src")))
# Out:
# ✓ src/__init__.py
# ✓ src/data_ingestion.py
# ✓ src/qc_preprocessing.py
# ✓ src/clustering_annotation.py
# ✓ src/trajectory_analysis.py
# ✓ src/de_enrichment.py
# ✓ src/ml_biomarker.py
# ✓ src/cell_communication.py
# ✓ src/dashboard.py
# ✓ configs/config.yaml
# ✓ Snakefile
# ✓ Dockerfile
# ✓ environment.yml
# ✓ data/download_instructions.md
#
# All files ready!
# src/: ['de_enrichment.py', 'qc_preprocessing.py', 'data_ingestion.py', 'ml_biomarker.py', '__init__.py', 'trajectory_analysis.py', 'cell_communication.py', 'dashboard.py', 'clustering_annotation.py']
